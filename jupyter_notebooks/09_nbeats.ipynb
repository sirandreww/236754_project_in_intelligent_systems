# %% [markdown]
# # N-BEATS
#
# Information can be found here:
# https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nbeats.html

# %%
import src.darts__nbeats as nbeats
import src.framework__test_bench as tb

# %%
tb = tb.TestBench(
    class_to_test=nbeats.DartsNBEATSTester,
    path_to_data="./data/",
)
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Fetching data for metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# 2022-07-18 21:06:30 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 3599 samples.
# [TEST BENCH] Throwing out data that is less than 15.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test
# [TEST BENCH] Amount of train/test data is 61
# [TEST BENCH] Making an instance of the class we want to test
# [TEST BENCH] Starting training loop
# 2022-07-18 21:06:30 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-18 21:06:30 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-18 21:06:30 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-18 21:06:30 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-18 21:06:30 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-18 21:06:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-18 21:06:34 pytorch_lightning.callbacks.model_summary INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.1 M
# ---------------------------------------------------
# 6.1 M     Trainable params
# 1.3 K     Non-trainable params
# 6.1 M     Total params
# 24.276    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# 2022-07-18 21:09:44 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [TEST BENCH] Training took 193.83368492126465 seconds.
# [TEST BENCH] Starting testing loop
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:45 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:46 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:47 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:47 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:48 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:49 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:50 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:52 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:53 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:54 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:54 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:55 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:55 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:56 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:57 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:57 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:58 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:58 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:09:59 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:00 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:00 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:01 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:01 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:02 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:03 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:03 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:04 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:04 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:05 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:06 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:06 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:07 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:07 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:08 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:09 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:09 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:10 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:11 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:11 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:12 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:12 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:14 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:16 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:17 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:17 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:18 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:19 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:19 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:20 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:21 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:21 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:22 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:23 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:24 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:24 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:25 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# 2022-07-18 21:10:26 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 113it [00:00, ?it/s]
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='node_mem', app='moc/smaug':
# [TEST BENCH] Training time in seconds is             193.83368492126465
# [TEST BENCH] Average mse over the test set is        0.009680892318093172
# [TEST BENCH] Average precision over the test set is  0.5588754142032831
# [TEST BENCH] Average recall over the test set is     0.7706769096113357
# [TEST BENCH] Average F1 over the test set is         0.6367855720728034
# [TEST BENCH] Average MASE over the test set is       229.87728674436508
# [TEST BENCH] Average MAPE over the test set is       14.919674229543578
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='node_mem', app='moc/smaug'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | node_mem | moc/smaug | 194 seconds   | 0.00968 | 0.55888 | 0.77068 | 0.63679  | 229.87729 | 14.91967 |
# [TEST BENCH] This test was run on:
# [TEST BENCH] GPU
# [TEST BENCH] Device name: NVIDIA GeForce RTX 2080
# Mon Jul 18 21:10:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:0F:00.0 Off |                  N/A |
# | 22%   49C    P2    60W / 215W |   3801MiB /  7982MiB |      9%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      9003      C   ...da3/envs/py310/bin/python      939MiB |
# |    0   N/A  N/A      9074      C   ...da3/envs/py310/bin/python      977MiB |
# |    0   N/A  N/A      9272      C   ...da3/envs/py310/bin/python      941MiB |
# |    0   N/A  N/A      9591      C   ...da3/envs/py310/bin/python      941MiB |
# +-----------------------------------------------------------------------------+
# [TEST BENCH] Powering off test bench
