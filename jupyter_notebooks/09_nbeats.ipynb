# %% [markdown]
# # N-BEATS
#
# Information can be found here:
# https://unit8co.github.io/darts/generated_api/darts.models.forecasting.nbeats.html

# %%
import src.darts__nbeats as nbeats
import src.framework__test_bench as tb

# %%
tb = tb.TestBench(
    class_to_test=nbeats.DartsNBEATSTester,
    path_to_data="./data/",
)
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Fetching data for metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 15.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test
# [TEST BENCH] Amount of train/test data is 61
# [TEST BENCH] Making an instance of the class we want to test
# [TEST BENCH] Starting training loop
# 2022-07-19 10:54:11 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 3599 samples.
# 2022-07-19 10:54:13 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-19 10:54:13 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-19 10:54:13 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-19 10:54:13 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-19 10:54:13 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-19 10:54:26 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-19 10:54:26 pytorch_lightning.callbacks.model_summary INFO:
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | stacks        | ModuleList       | 6.1 M
# ---------------------------------------------------
# 6.1 M     Trainable params
# 1.3 K     Non-trainable params
# 6.1 M     Total params
# 24.276    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# [TEST BENCH] Training took 36.55512523651123 seconds.
# [TEST BENCH] Starting testing loop
# 2022-07-19 10:54:48 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 29it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       1 tb = tb.TestBench(
#       2     class_to_test=nbeats.DartsNBEATSTester,
#       3     path_to_data="./data/",
#       4 )
# ----> 5 tb.run_training_and_tests()
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:343, in TestBench.run_training_and_tests(self)
#     341     metric = dictionary["metric"]
#     342     print(self.__msg, f"testing metric='{metric}', app='{app}'.")
# --> 343     mse, precision, recall, f1, training_time, mase, mape = self.__do_one_test(dictionary=dictionary)
#     344     full_report += [(mse, precision, recall, f1, training_time, mase, mape)]
#     345 assert len(full_report) == len(self.__tests_to_perform)
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:300, in TestBench.__do_one_test(self, dictionary)
#     298 print(self.__msg, f"Training took {training_time} seconds.")
#     299 print(self.__msg, "Starting testing loop")
# --> 300 mse, precision, recall, f1, mase, mape = self.__test_model(test=test, model=model)
#     301 self.__print_report(
#     302     metric=metric, app=app, mse=mse, precision=precision, recall=recall, f1=f1,
#     303     training_time=training_time, mase=mase, mape=mape
#     304 )
#     305 print(self.__msg, f"Done with metric='{metric}', app='{app}'")
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:270, in TestBench.__test_model(self, test, model)
#     268 total_mape = 0
#     269 for i, test_sample in enumerate(test):
# --> 270     mse_here, precision, recall, f1, mase, mape = self.__give_one_test_to_model(
#     271         test_sample=test_sample, model=model, should_print=(i < 10)
#     272     )
#     273     total_mse += mse_here
#     274     total_precision += precision
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:222, in TestBench.__give_one_test_to_model(self, test_sample, model, should_print)
#     217     plot_result(
#     218         original=test_sample,
#     219         prediction_as_np_array=returned_ts_as_np_array,
#     220     )
#     221 out_should_be = test_sample["sample"].to_numpy()
# --> 222 mse_here, precision, recall, f1, mase, mape = self.__get_mse_precision_recall_f1_mase_and_mape(
#     223     y_true=out_should_be[how_much_to_give:], y_pred=returned_ts_as_np_array,
#     224     y_train=out_should_be[:how_much_to_give]
#     225 )
#     226 return mse_here, precision, recall, f1, mase, mape
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:169, in TestBench.__get_mse_precision_recall_f1_mase_and_mape(y_true, y_pred, y_train)
#     163 """
#     164 @param y_true: true values
#     165 @param y_pred: prediction values
#     166 @return: the mse, precision_recall_f1 and MASE of the results
#     167 """
#     168 assert len(y_true) == len(y_pred)
# --> 169 mse_here = TestBench.__calculate_mse(y_pred=y_pred, y_true=y_true)
#     171 actual_positives = [y_true[i + 1] >= y_true[i] for i in range(len(y_true) - 1)]
#     172 predicted_positives = [y_pred[i + 1] >= y_pred[i] for i in range(len(y_pred) - 1)]
#
# File ~/project_in_intelligent_systems/236754_project_in_intelligent_systems/jupyter_notebooks/src/framework__test_bench.py:157, in TestBench.__calculate_mse(y_true, y_pred)
#     154 @staticmethod
#     155 def __calculate_mse(y_true, y_pred):
#     156     mse = MeanSquaredError()
# --> 157     result = mse(y_true=y_true, y_pred=y_pred)
#     158     assert result == (np.square(y_true - y_pred)).mean()
#     159     return result
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sktime/performance_metrics/forecasting/_classes.py:131, in BaseForecastingErrorMetric.__call__(self, y_true, y_pred, **kwargs)
#     106 def __call__(self, y_true, y_pred, **kwargs):
#     107     """Calculate metric value using underlying metric function.
#     108
#     109     Parameters
#    (...)
#     129             i-th entry is metric calculated for i-th variable
#     130     """
# --> 131     return self.evaluate(y_true, y_pred, **kwargs)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sktime/performance_metrics/forecasting/_classes.py:165, in BaseForecastingErrorMetric.evaluate(self, y_true, y_pred, **kwargs)
#     161 y_true_inner, y_pred_inner, multioutput, multilevel, kwargs = self._check_ys(
#     162     y_true, y_pred, multioutput, multilevel, **kwargs
#     163 )
#     164 # pass to inner function
# --> 165 out_df = self._evaluate(y_true=y_true_inner, y_pred=y_pred_inner, **kwargs)
#     167 return out_df
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sktime/performance_metrics/forecasting/_classes.py:404, in BaseForecastingErrorMetricFunc._evaluate(self, y_true, y_pred, **kwargs)
#     402 params.update(kwargs)
#     403 # we need to call type since we store func as a class attribute
# --> 404 res = type(self).func(y_true=y_true, y_pred=y_pred, **params)
#     405 return res
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sktime/performance_metrics/forecasting/_functions.py:1008, in mean_squared_error(y_true, y_pred, horizon_weight, multioutput, square_root, **kwargs)
#    1003 # Scikit-learn argument `squared` returns MSE when True and RMSE when False
#    1004 # Scikit-time argument `square_root` returns RMSE when True and MSE when False
#    1005 # Therefore need to pass the opposite of square_root as squared argument
#    1006 # to the scikit-learn function being wrapped
#    1007 squared = not square_root
# -> 1008 return _mean_squared_error(
#    1009     y_true,
#    1010     y_pred,
#    1011     sample_weight=horizon_weight,
#    1012     multioutput=multioutput,
#    1013     squared=squared,
#    1014 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_regression.py:102, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     100 check_consistent_length(y_true, y_pred)
#     101 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 102 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     104 if y_true.ndim == 1:
#     105     y_true = y_true.reshape((-1, 1))
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/utils/validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN.
