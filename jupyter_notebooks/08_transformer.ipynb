# %% [markdown]
# # Transformer
#
# Information can be found here:
# https://unit8co.github.io/darts/generated_api/darts.models.forecasting.transformer_model.html

# %%
import src.darts__transformer as transformer
import src.framework__test_bench as tb

# %%
tb = tb.TestBench(
    class_to_test=transformer.DartsTransformerTester,
    path_to_data="./data/",
)
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Fetching data for metric='node_mem', app='moc/smaug'.
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# 2022-07-19 13:17:00 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 3599 samples.
# [TEST BENCH] Throwing out data that is less than 15.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test
# [TEST BENCH] Amount of train/test data is 61
# [TEST BENCH] Making an instance of the class we want to test
# [TEST BENCH] Starting training loop
# 2022-07-19 13:17:00 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-19 13:17:00 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-19 13:17:00 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-19 13:17:00 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-19 13:17:00 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-19 13:17:03 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-19 13:17:03 pytorch_lightning.callbacks.model_summary INFO:
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | criterion           | MSELoss             | 0
# 1 | train_metrics       | MetricCollection    | 0
# 2 | val_metrics         | MetricCollection    | 0
# 3 | encoder             | Linear              | 32
# 4 | positional_encoding | _PositionalEncoding | 0
# 5 | transformer         | Transformer         | 23.9 K
# 6 | decoder             | Linear              | 17
# ------------------------------------------------------------
# 23.9 K    Trainable params
# 0         Non-trainable params
# 23.9 K    Total params
# 0.096     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# 2022-07-19 13:17:12 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [TEST BENCH] Training took 11.970246076583862 seconds.
# [TEST BENCH] Starting testing loop
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:12 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:14 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:14 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:16 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:16 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:17 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:17 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting:
pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:27 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# 2022-07-19 13:17:27 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 15it [00:00, ?it/s]
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='node_mem', app='moc/smaug':
# [TEST BENCH] Training time in seconds is             11.970246076583862
# [TEST BENCH] Average mse over the test set is        0.6657207212350738
# [TEST BENCH] Average precision over the test set is  0.012021857923497267
# [TEST BENCH] Average recall over the test set is     0.01639344262295082
# [TEST BENCH] Average F1 over the test set is         0.01387137452711223
# [TEST BENCH] Average MASE over the test set is       1949.0311398565566
# [TEST BENCH] Average MAPE over the test set is       2.862556561523388
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='node_mem', app='moc/smaug'
# [TEST BENCH] testing metric='node_mem', app='emea/balrog'.
# [TEST BENCH] Fetching data for metric='node_mem', app='emea/balrog'.
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# 2022-07-19 13:17:29 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 320 samples.
# 2022-07-19 13:17:29 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-19 13:17:29 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-19 13:17:29 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-19 13:17:29 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-19 13:17:29 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-19 13:17:29 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-19 13:17:29 pytorch_lightning.callbacks.model_summary INFO:
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | criterion           | MSELoss             | 0
# 1 | train_metrics       | MetricCollection    | 0
# 2 | val_metrics         | MetricCollection    | 0
# 3 | encoder             | Linear              | 32
# 4 | positional_encoding | _PositionalEncoding | 0
# 5 | transformer         | Transformer         | 23.9 K
# 6 | decoder             | Linear              | 17
# ------------------------------------------------------------
# 23.9 K    Trainable params
# 0         Non-trainable params
# 23.9 K    Total params
# 0.096     Total estimated model params size (MB)
# [TEST BENCH] Throwing out data that is less than 15.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test
# [TEST BENCH] Amount of train/test data is 20
# [TEST BENCH] Making an instance of the class we want to test
# [TEST BENCH] Starting training loop
# Training: 0it [00:00, ?it/s]
# 2022-07-19 13:17:31 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [TEST BENCH] Training took 1.8566782474517822 seconds.
# [TEST BENCH] Starting testing loop
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:31 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:32 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:35 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:37 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:38 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:38 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:38 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:40 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:40 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# 2022-07-19 13:17:40 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 2it [00:00, ?it/s]
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='node_mem', app='emea/balrog':
# [TEST BENCH] Training time in seconds is             1.8566782474517822
# [TEST BENCH] Average mse over the test set is        0.2756045805411287
# [TEST BENCH] Average precision over the test set is  0.32999999999999996
# [TEST BENCH] Average recall over the test set is     0.5
# [TEST BENCH] Average F1 over the test set is         0.39179972950587644
# [TEST BENCH] Average MASE over the test set is       7940.450613518398
# [TEST BENCH] Average MAPE over the test set is       1.007101714687416
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='node_mem', app='emea/balrog'
# [TEST BENCH] testing metric='container_mem', app='nmstate-handler'.
# [TEST BENCH] Fetching data for metric='container_mem', app='nmstate-handler'.
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 15.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test
# [TEST BENCH] Amount of train/test data is 497
# [TEST BENCH] Making an instance of the class we want to test
# [TEST BENCH] Starting training loop
# 2022-07-19 13:18:44 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 65107 samples.
# 2022-07-19 13:18:44 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-19 13:18:44 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-19 13:18:44 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-19 13:18:44 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-19 13:18:44 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-19 13:18:44 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:32 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:32 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:32 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# 2022-07-19 14:53:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 273it [00:00, ?it/s]
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='container_cpu', app='collector':
# [TEST BENCH] Training time in seconds is             245.70654201507568
# [TEST BENCH] Average mse over the test set is        0.4171026452011869
# [TEST BENCH] Average precision over the test set is  0.25429143309327673
# [TEST BENCH] Average recall over the test set is     0.40211122083241924
# [TEST BENCH] Average F1 over the test set is         0.2799589813554891
# [TEST BENCH] Average MASE over the test set is       4.896054181196115
# [TEST BENCH] Average MAPE over the test set is       3.497422171256755
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='container_cpu', app='collector'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | node_mem | moc/smaug | 12 seconds   | 0.66572 | 0.01202 | 0.01639 | 0.01387  | 1949.03114 | 2.86256 |
# [TEST BENCH] | node_mem | emea/balrog | 2 seconds   | 0.2756 | 0.33 | 0.5 | 0.3918  | 7940.45061 | 1.0071 |
# [TEST BENCH] | container_mem | nmstate-handler | 213 seconds   | 1.01039 | 0.47159 | 0.76281 | 0.56743  | 0.92472 | 2.29103 |
# [TEST BENCH] | container_mem | coredns | 295 seconds   | 0.03324 | 0.44873 | 0.65695 | 0.4768  | 1.68156 | 0.87073 |
# [TEST BENCH] | container_mem | keepalived | 415 seconds   | 0.0162 | 0.52166 | 0.94892 | 0.66826  | 1.73954 | 0.6174 |
# [TEST BENCH] | container_cpu | kube-rbac-proxy | 2262 seconds   | 0.1332 | 0.48389 | 0.60254 | 0.48733  | 1.59415 | 1.37784 |
# [TEST BENCH] | container_cpu | dns | 466 seconds   | 0.13634 | 0.47713 | 0.79038 | 0.57329  | 1.68745 | 1.88919 |
# [TEST BENCH] | container_cpu | collector | 246 seconds   | 0.4171 | 0.25429 | 0.40211 | 0.27996  | 4.89605 | 3.49742 |
# [TEST BENCH] This test was run on:
# [TEST BENCH] GPU
# [TEST BENCH] Device name: NVIDIA GeForce RTX 2080
# Tue Jul 19 14:53:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:07:00.0 Off |                  N/A |
# | 27%   60C    P2    45W / 215W |   6730MiB /  7982MiB |     21%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2534      C   ...da3/envs/py310/bin/python      965MiB |
# |    0   N/A  N/A     30383      C   ...da3/envs/py310/bin/python      987MiB |
# |    0   N/A  N/A     33674      C   ...da3/envs/py310/bin/python      977MiB |
# |    0   N/A  N/A     33703      C   ...da3/envs/py310/bin/python      939MiB |
# |    0   N/A  N/A     33720      C   ...da3/envs/py310/bin/python      977MiB |
# |    0   N/A  N/A     55184      C   ...da3/envs/py310/bin/python      943MiB |
# |    0   N/A  N/A     64025      C   ...da3/envs/py310/bin/python      939MiB |
# +-----------------------------------------------------------------------------+
# [TEST BENCH] Powering off test bench
